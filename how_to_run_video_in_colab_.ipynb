# %% [markdown]
# <a href="https://colab.research.google.com/github/RokonUZ/Colab/blob/main/how_to_run_video_in_colab_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#upload a video in colab content folder and copy the path

# %%
video_path="/content/output.mp4"

video_width = 600

# %%
from IPython.display import HTML
from base64 import b64encode

# %%
video_file = open(video_path, "r+b").read()

video_url = f"data:video/mp4;base64,{b64encode(video_file).decode()}"
HTML(f"""<video width={video_width} controls><source src="{video_url}"></video>""")
# Out:
# <video width=600 controls><source src="data:video/mp4;base64,..."></video>
